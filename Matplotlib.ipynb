# %% [markdown]
# # MATPLOTLIB Library

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.20.3

# %%
"""Using Numpy to generate random data
"""
import numpy as np
x=np.linspace(0, 10, 25 )
y=x*x+2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
"""one command to draw
"""
pylab.plot(x,y,'r') # r means red color

# %%
"""Drawing a sub graph
"""
pylab.subplot(1,2,1) # the content of the brackets represent(rows, column, indexes)
pylab.plot(x,y, 'r--')# the third parameter here determines the color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g*-')

# %% [markdown]
# # Operator Description
#
# fig.add_axis()                                   = initializes subplot
# a= fig.add_subplot(222)
#
# fig,b =subplots(nrows=3 ,nclos=2)                = Adds subplot
#
# ax=plt.subplots(2,2)                             = Creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig= plt.figure()

axis=fig.add_axes([0.5,0.1,0.8,0.8])# Controls the left, right, width, height of the canvas(from 0 to 1)

axis.plot(x,y, 'r')

# %%
# we can again draw subgraphs
fig, axes=plt.subplots(nrows=1 , ncols=2)# Submap is of 1 row, 2 columns
for ax in axes:
        ax.plot(x,y,'r')

# %%
# we can also draw a picture, or graph, inside another graph
fig=plt.figure()

#control the left , bottom , width , height of the canvas(from 0 to 1)
axes1= fig.add_axes([0.1,0.1,0.8,0.8])# big axes
axes2= fig.add_axes([0.2,0.5,0.4,0.3])# small canvas

axes1.plot(x,y,'r')
axes2.plot(y,x,'g')

# %%
fig = plt.figure(figsize=(16,9), dpi=300)# New graphic object

fig.add_subplot()

plt.plot(x,y,'r')

# %%
ax.legend(["label1", "label2"])

fig,axes = plt.subplots(dpi=300)
axes.set_xlabel("x- Label")
axes.set_ylabel("y- Label")

axes.set_title("Title of Graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

axes.legend(["y= x**2", "y=x**3"], loc=2)

# %%
# In Matplotlib, you can set other properties such as line color, transparency, and more.

fig, axes = plt.subplots(dpi=150,)
axes.plot(x, x**2, color='green',alpha=.5)
axes.plot(x, x+2, color='red',alpha=.5)
axes.plot(x, x+3, color='purple',alpha=.5)

# %%
fig,ax = plt.subplots(dpi=100) 

#Line with
ax.plot(x, x+1, color='blue', linewidth=0.25 )
ax.plot(x, x+2, color='blue', linewidth=1 )
ax.plot(x, x+3, color='blue', linewidth=1.5 )
ax.plot(x, x+4, color='blue', linewidth=2)

# %%
fig,ax = plt.subplots(dpi=100) 

#Line with
ax.plot(x, x+1, color='blue', lw=2,linestyle='-' )
ax.plot(x, x+2, color='blue', lw=2,linestyle='-.' )
ax.plot(x, x+3, color='blue', lw=2,linestyle=':' )

line,= ax.plot(x, x+4, color='black',lw=1.50)
line.set_dashes([5, 10, 15, 10])

line,= ax.plot(x, x+5, color='black',lw=1.50)
line.set_dashes([5, 10, 15, 3])

line,= ax.plot(x, x+6, color='black',lw=1.50)
line.set_dashes([5, 10, 4, 10])

# %%
fig,ax = plt.subplots(dpi=100) 

ax.plot(x, x+1, color='blue', marker='o')
ax.plot(x, x+2, color='blue', marker='+')
ax.plot(x, x+3, color='blue', marker='s')
ax.plot(x, x+4, color='blue', marker='1')

ax.plot(x, x+5, color="blue",marker='o', markersize=5)
ax.plot(x, x+6, color='blue', marker='s', markerfacecolor='red')
ax.plot(x, x+7, color='blue', marker='o',markersize=8,markerfacecolor='green')

# %%
"""Set the canvas grid and axis range
"""
fig,axes = plt.subplots(1,2, figsize=(10,5))

axes[0].plot(x, x**2, x , x**3, lw=2)
axes[0].grid(True)

axes[1].plot(x, x**2, x , x**3, lw=2)
axes[1].grid(True)
axes[1].set_ylim([0,60])
axes[1].set_xlim([2,5])
# Out:
# (2.0, 5.0)

# %% [markdown]
# # Other 2D Graphics

# %%
n=np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize=(16,5))

axes[0].set_title('Scatter plot')
axes[0].scatter (x, x+0.25*np.random.randn(len(x)))

axes[1].set_title('Step plot')
axes[1].step(n, n**2, lw=2)

axes[2].set_title('Bar plot')
axes[2].bar(n, n**2, align="center" , alpha=1)

axes[3].set_title('Fill Between')
axes[3].fill_between(x, x**2,x**3,color="green",alpha=1)

# %%
"""Drawing a radar chart
"""
fig=plt.figure(figsize=(6,6))
ax=fig.add_axes([0.0,0.0,1,1],polar=True)
t= np.linspace(0,2*np.pi,100)
ax.plot(t,t, color='blue', lw=3)

# %%
"""Drawing a histogram
"""
n=np.random.randn(100000)
fig,axes =plt.subplots(1,2,figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=10)
# Out:
# (array([6.0000e+00, 2.3000e+02, 2.8320e+03, 1.5501e+04, 4.5085e+04,
#         7.7837e+04, 9.4993e+04, 9.9469e+04, 9.9970e+04, 1.0000e+05]),
#  array([-4.58366102, -3.69204297, -2.80042493, -1.90880689, -1.01718884,
#         -0.1255708 ,  0.76604724,  1.65766529,  2.54928333,  3.44090137,
#          4.33251941]),
#  <BarContainer object of 10 artists>)

# %%
#Drawing Contour Image

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y =np.meshgrid(x,y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1- Z2)* 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('Contour map')
# Out:
# Text(0.5, 1.0, 'Contour map')
